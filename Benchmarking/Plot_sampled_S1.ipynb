# %%
library(zoo)
# Out:
# Attaching package: 'zoo'
#
# The following objects are masked from 'package:base':
#
#     as.Date, as.Date.numeric

# %%
ifolder <- 'C:\\Users\\keers001\\OneDrive\ -\ WageningenUR\\RETURN\\Data\\RETURN\\20191019_SimulationOptSAR\\S1\\SampledData\\'
nfolder <- 'C:\\Users\\keers001\\Dropbox\\output\\Jupyter_notebook\\'

system(paste0('jupyter-nbconvert.exe ', nfolder, 'sim_Functions.ipynb  --to script'))#, intern=FALSE
source(file.path(nfolder, 'sim_Functions.r'))

for (i in 1:10){
    ifileVH <- paste0('S1_VH_pix_', i, '.rda')
dfVH <- loadRData(file = file.path(ifolder, ifileVH))
ifileVV <- paste0('S1_VV_pix_', i, '.rda')
dfVV <- loadRData(file = file.path(ifolder, ifileVV))


head(dfVH)
#plot(as.numeric(dfVH[-c(1,2)], type = 'o'))
tsi <- dfVH[-c(1,2)]
tmi <- as.Date(names(dfVH[-c(1,2)]))
tsi2 <- dfVV[-c(1,2)]
tmi2 <- as.Date(names(dfVV[-c(1,2)]))
ymin <- min(cbind(tsi, tsi2), na.rm=T)
ymax <- max(cbind(tsi, tsi2), na.rm=T)
plot(zoo(tsi[is.na(tsi)==F], tmi[is.na(tsi)==F]), type='o', lw = 2, xlab= 'Time [year]', ylab= 'VH gamma-0 [dB]',
       col='green', ylim=c(ymin,ymax))
lines(zoo(tsi2[is.na(tsi2)==F], tmi2[is.na(tsi2)==F]), type='o', lw = 2,
       col='red')


}
# Out:
# [1] 0
# Plot with title ""
# Plot with title ""
# Plot with title ""
# Plot with title ""
# Plot with title ""
# Plot with title ""
# Plot with title ""
# Plot with title ""
# Plot with title ""
# Plot with title ""
