# %% [markdown]
# # Test recovery indicators

# %% [markdown]
# ## Libraries

# %%
library(testthat)

# %% [markdown]
# ## Unit test of recovery metrics on dense, raw time series

# %%
test_that("Test RRI dense raw",{
nfolder <- 'C:\\Users\\keers001\\Dropbox\\output\\Jupyter_notebook\\'
system(paste0('jupyter-nbconvert.exe ', nfolder, 'rec_Functions.ipynb  --to script'))#, intern=FALSE
source(file.path(nfolder, 'rec_Functions.r'))
tsi <- c(rep(5,24), rep(1,12),rep(3,24), rep(4,26))
tdist <- 25
obspyr <- 12

shortDenseTS <- T
nPre <- 2
nDist <- 12
nPostMin <- 3
nPostMax <-5

rec <- calcFrazier(tsi, tdist, obspyr, shortDenseTS, nPre, nDist, nPostMin, nPostMax)
    expect_equal(rec[['RRI']], (4-1)/(5-1))
    expect_equal(rec[['R80P']], (4)/(5*0.8))
    expect_equal(rec[['YrYr']], (4-1)/4)
})

# %% [markdown]
# ## Unit test of recovery metrics on annual, raw time series

# %%
test_that("Test RRI annual raw",{
nfolder <- 'C:\\Users\\keers001\\Dropbox\\output\\Jupyter_notebook\\'
system(paste0('jupyter-nbconvert.exe ', nfolder, 'rec_Functions.ipynb  --to script'))#, intern=FALSE
source(file.path(nfolder, 'rec_Functions.r'))
tsi <- c(rep(5,24), rep(1,12),rep(3,24), rep(4,36))
tsi <- toAnnualTS(rep(c(1,2,3,4,5,6,7,6,5,4,3,2),8),tsi,12)
tdist <- ceiling(25/12)
obspyr <- 1

shortDenseTS <- F
nPre <- 2
nDist <- 12
nPostMin <- 3
nPostMax <-5

rec <- calcFrazier(tsi, tdist, obspyr, shortDenseTS, nPre, nDist, nPostMin, nPostMax)
    expect_equal(rec[['RRI']], (4-1)/(5-1))
    expect_equal(rec[['R80P']], (4)/(5*0.8))
    expect_equal(rec[['YrYr']], (4-1)/5)
})

# %% [markdown]
# ## Test decomposition time series

# %%
test_that("Test decomposition",{
nfolder <- 'C:\\Users\\keers001\\Dropbox\\output\\Jupyter_notebook\\'
system(paste0('jupyter-nbconvert.exe ', nfolder, 'sim_Functions.ipynb  --to script'))#, intern=FALSE
source(file.path(nfolder, 'sim_Functions.r'))

    tri <- c(rep(5,24), rep(1,12),rep(3,24), rep(4,36))
    seasi <- rep(c(1,2,3,4,5,6,7,6,5,4,3,2),8)
    remi <- runif(96)
    tsi <- tri+seasi+remi
    tsi <- c(1,2,tsi)
    df <- as.data.frame(matrix(tsi,nrow =1))
    names(df) <- c('lat','lon',seq(as.Date('2000-1-1'),as.Date('2007-12-1'),by='1 months'))
    
    decompTSbfast(df, 8, 12)
rec <- calcFrazier(tsi, tdist, obspyr, shortDenseTS, nPre, nDist, nPostMin, nPostMax)
    expect_equal(rec[['RRI']], (4-1)/(5-1))
    expect_equal(rec[['R80P']], (4)/(5*0.8))
    expect_equal(rec[['YrYr']], (4-1)/5)
})

# %%
nfolder <- 'C:\\Users\\keers001\\Dropbox\\output\\Jupyter_notebook\\'
system(paste0('jupyter-nbconvert.exe ', nfolder, 'sim_Functions.ipynb  --to script'))#, intern=FALSE
source(file.path(nfolder, 'sim_Functions.r'))
tri <- c(seq(1,5,length.out=96))
seasi <- rep(c(1,2,3,4,5,6,7,6,5,4,3,2),8)
remi <- runif(96)/1
tsi <- tri+seasi+remi
dts <- seq(as.Date('2000-1-1'),as.Date('2007-12-1'),by='1 months')
tsi <- c(1,2,tsi)
df <- as.data.frame(matrix(tsi,nrow =1))
names(df) <- c('lat','lon',dts)

dc <- decompTSbfast(df, 8, 12)
dc$Trend[,-c(1,2)]
tri+mean(seasi)+mean(remi)
dc$Seasonality[,-c(1,2)]
#plot((seasi-mean(seasi))); lines(as.numeric(dc$Seasonality[,-c(1,2)]), col='red')
#plot((tri+mean(seasi)+mean(remi))); lines(as.numeric(dc$Trend[,-c(1,2)]), col='red')
#decompTSbfast(df, nyr, nobsYr)
# Out:
# [1] 0
#   10957    10988   11017    11048    11078   11109    11139    11170   11201
# 1 5.405974 5.44995 5.493927 5.537903 5.58188 5.625857 5.669833 5.71381 5.757786
#   11231    ... 13573    13604    13634    13665   13695    13726    13757
# 1 5.801763 ... 9.187961 9.231937 9.275914 9.31989 9.363867 9.407843 9.45182
#   13787    13818    13848
# 1 9.495797 9.539773 9.58375
#  [1] 5.494862 5.536967 5.579072 5.621177 5.663283 5.705388 5.747493 5.789599
#  [9] 5.831704 5.873809 5.915914 5.958020 6.000125 6.042230 6.084335 6.126441
# [17] 6.168546 6.210651 6.252756 6.294862 6.336967 6.379072 6.421177 6.463283
# [25] 6.505388 6.547493 6.589599 6.631704 6.673809 6.715914 6.758020 6.800125
# [33] 6.842230 6.884335 6.926441 6.968546 7.010651 7.052756 7.094862 7.136967
# [41] 7.179072 7.221177 7.263283 7.305388 7.347493 7.389599 7.431704 7.473809
# [49] 7.515914 7.558020 7.600125 7.642230 7.684335 7.726441 7.768546 7.810651
# [57] 7.852756 7.894862 7.936967 7.979072 8.021177 8.063283 8.105388 8.147493
# [65] 8.189599 8.231704 8.273809 8.315914 8.358020 8.400125 8.442230 8.484335
# [73] 8.526441 8.568546 8.610651 8.652756 8.694862 8.736967 8.779072 8.821177
# [81] 8.863283 8.905388 8.947493 8.989599 9.031704 9.073809 9.115914 9.158020
# [89] 9.200125 9.242230 9.284335 9.326441 9.368546 9.410651 9.452756 9.494862
#   10957     10988     11017     11048       11078    11109    11139    11170
# 1 -2.494674 -2.169687 -1.263334 -0.01847235 1.231339 2.151215 2.494674 2.169687
#   11201    11231      ... 13573     13604       13634    13665    13695
# 1 1.263334 0.01847235 ... -1.263334 -0.01847235 1.231339 2.151215 2.494674
#   13726    13757    13787      13818     13848
# 1 2.169687 1.263334 0.01847235 -1.231339 -2.151215
