# %% [markdown]
# ## Plot Sampled Landsat time series

# %%
library(zoo)
ifolder <- 'C:\\Users\\keers001\\OneDrive\ -\ WageningenUR\\RETURN\\Data\\RETURN\\20191019_SimulationOptSAR\\Landsat\\SampledData'
charfolder <-'C:\\Users\\keers001\\OneDrive\ -\ WageningenUR\\RETURN\\Data\\RETURN\\20191019_SimulationOptSAR\\Landsat\\Char'
sampledVI <- 'LSTS_RndmSample_NoFire_5_Tree_80_scl_30_npnt_20000_VI.rda'
nfolder <- 'C:\\Users\\keers001\\Dropbox\\output\\Jupyter_notebook\\'

system(paste0('jupyter-nbconvert.exe ', nfolder, 'sim_Functions.ipynb  --to script'))#, intern=FALSE
source(file.path(nfolder, 'sim_Functions.r'))
# Out:
# Attaching package: 'zoo'
#
# The following objects are masked from 'package:base':
#
#     as.Date, as.Date.numeric
# [1] 0

# %%
load(file.path(ifolder, sampledVI))
tsVI <- loadRData(file.path(ifolder, sampledVI))
tsSeas <- loadRData(file.path(charfolder, 'LSTS_RndmSample_NoFire_5_Tree_80_scl_30_npnt_20000_VI_Seasbf.rda'))
tsTr <- loadRData(file.path(charfolder, 'LSTS_RndmSample_NoFire_5_Tree_80_scl_30_npnt_20000_VI_Trbf.rda'))
tsRem <- loadRData(file.path(charfolder, 'LSTS_RndmSample_NoFire_5_Tree_80_scl_30_npnt_20000_VI_Rembf.rda'))
seasVImax <- loadRData(file.path(charfolder, 'LSTS_RndmSample_NoFire_5_Tree_80_scl_30_npnt_20000_VI_SeasVImax.rda'))
seasVImean <- loadRData(file.path(charfolder, 'LSTS_RndmSample_NoFire_5_Tree_80_scl_30_npnt_20000_VI_SeasVImean.rda'))
seasRemcoef <- loadRData(file.path(charfolder, 'LSTS_RndmSample_NoFire_5_Tree_80_scl_30_npnt_20000_VI_Rem_VIcoef.rda'))
seasRemsd <- loadRData(file.path(charfolder, 'LSTS_RndmSample_NoFire_5_Tree_80_scl_30_npnt_20000_VI_Rem_VIsd.rda'))
dts <- as.Date(names(seasVImean))

# %%
dim(tsVI)
dim(tsSeas)
length(seasVImax)
mean(seasVImax)
names(seasVImean)
mean(as.numeric(tsTr[1,]))
# Out:
# [1] 1000 6576
# [1] 1000 6576
# [1] 1000
# [1] 0.02344442
#    [1] "2001-01-01" "2001-01-02" "2001-01-03" "2001-01-04" "2001-01-05"
#    [6] "2001-01-06" "2001-01-07" "2001-01-08" "2001-01-09" "2001-01-10"
#   [11] "2001-01-11" "2001-01-12" "2001-01-13" "2001-01-14" "2001-01-15"
#   [16] "2001-01-16" "2001-01-17" "2001-01-18" "2001-01-19" "2001-01-20"
#   [21] "2001-01-21" "2001-01-22" "2001-01-23" "2001-01-24" "2001-01-25"
#   [26] "2001-01-26" "2001-01-27" "2001-01-28" "2001-01-29" "2001-01-30"
#   [31] "2001-01-31" "2001-02-01" "2001-02-02" "2001-02-03" "2001-02-04"
#   [36] "2001-02-05" "2001-02-06" "2001-02-07" "2001-02-08" "2001-02-09"
#   [41] "2001-02-10" "2001-02-11" "2001-02-12" "2001-02-13" "2001-02-14"
#   [46] "2001-02-15" "2001-02-16" "2001-02-17" "2001-02-18" "2001-02-19"
#   [51] "2001-02-20" "2001-02-21" "2001-02-22" "2001-02-23" "2001-02-24"
#   [56] "2001-02-25" "2001-02-26" "2001-02-27" "2001-02-28" "2001-03-01"
# ...

# %%
max(as.numeric(tsSeas[1,-c(1,2)]))
seasVImax[1]
tsi <- as.numeric(tsVI[1,-c(1,2)])
tsi2 <- as.numeric(tsSeas[1,-c(1,2)])+mean(as.numeric(tsTr[1,-c(1,2)]))
plot(zoo(tsi[is.na(tsi)==F], dts[is.na(tsi)==F]), type='o', lw = 2, xlab= 'Time [year]', ylab= 'NBR [-]',
       col='black')#, ylim=c(ymin,ymax)
#lines(zoo(tsi1[is.na(tsi2)==F], dts[is.na(tsi2)==F]), lw = 4,
#       col='coral2')
lines(zoo(tsi2[is.na(tsi2)==F], dts[is.na(tsi2)==F]), lw = 4,
       col='coral2')

# %%
# Offset
mean(as.numeric(tsTr[1,-c(1,2)]))
tsi <- as.numeric(tsVI[1,-c(1,2)])
tsi1 <- as.numeric(tsTr[1,-c(1,2)])
tsi2 <- rep(mean(as.numeric(tsTr[1,-c(1,2)])),length(tsi))
plot(zoo(tsi[is.na(tsi)==F], dts[is.na(tsi)==F]), type='o', lw = 2, xlab= 'Time [year]', ylab= 'NBR [-]',
       col='black')#, ylim=c(ymin,ymax)
#lines(zoo(tsi1[is.na(tsi2)==F], dts[is.na(tsi2)==F]), lw = 4,
#       col='coral2')
lines(zoo(tsi2[is.na(tsi2)==F], dts[is.na(tsi2)==F]), lw = 4,
       col='coral2')

# %%
# Remainder
2*seasVImax[1]
seasRemcoef[[1]]
seasRemsd[1]
tsi <- as.numeric(tsRem[1,-c(1,2)])
#tsi2 <- mean(as.numeric(tsTr[1,]))+ as.numeric(tsSeas[1,-c(1,2)])
plot(zoo(tsi[is.na(tsi)==F], dts[is.na(tsi)==F]), type='o', lw = 2, xlab= 'Time [year]', ylab= 'NBR [-]',
       col='black')#, ylim=c(ymin,ymax)
#lines(zoo(tsi2[is.na(tsi2)==F], dts[is.na(tsi2)==F]), lw = 4,
#       col='coral2')

# %%
# Distribution seasonality
#head(tsSeas)
seasS <- tsSeas[tsSeas[,1]<0,]# only southern hemisphere to avoid interference of seasonal cycles
#seasVImean <- colMeans(as.matrix(seasS[,-c(1,2)]))

tsi <- as.numeric(seasS[1,-c(1,2)])
#tsi2 <- mean(as.numeric(tsTr[1,]))+ as.numeric(tsSeas[1,-c(1,2)])
plot(zoo(tsi[is.na(tsi)==F], dts[is.na(tsi)==F]), lw = 1, xlab= 'Time [year]', ylab= 'NBR [-]',
       col='gray', ylim=c(-0.25,0.25))#
for(i in 2:dim(seasS)[1]){
  tsi <- as.numeric(seasS[i,-c(1,2)])
    lines(zoo(tsi[is.na(tsi)==F], dts[is.na(tsi)==F]), lw = 1,
       col='gray')  
}
lines(zoo(seasVImean[is.na(seasVImean)==F], dts[is.na(seasVImean)==F]), lw = 4,
       col='coral2')

# %%
# Distribution seasonality
#tsi2 <- mean(as.numeric(tsTr[1,]))+ as.numeric(tsSeas[1,-c(1,2)])
plot(zoo(seasVImean[is.na(seasVImean)==F], dts[is.na(seasVImean)==F]), lw = 3, xlab= 'Time [year]', ylab= 'NBR [-]',
       col='gray')#
mean(seasVImax)
max(seasVImean)*2

# %%
# Distribution amplitude
hist(2*seasVImax, xlab='Amplitude', main = '')

# %%
hist(seasRemsd, xlab='SD', main = '')

# %%
set <- loadRData('C:\\Users\\keers001\\OneDrive\ -\ WageningenUR\\RETURN\\Data\\RETURN\\20191019_SimulationOptSAR\\Landsat\\SimTS\\LSTS_RndmSample_NoFire_5_Tree_80_scl_30_npnt_20000_VI_VI_simTS_settings.rda')

# %%
names(set)
names(set$VnDr)
# Out:
# [1] "VnDr"     "Vnyr"     "VseasAmp" "VremSd"   "VdistMag" "VdistT"   "VdistRec"
# [8] "VmissVal"
#  [1] "variable"    "nrep"        "nyr"         "nobsYr"      "nDr"
#  [6] "seasAv"      "seasAmp"     "trAv"        "remSd"       "distMag"
# [11] "distT"       "distRec"     "missVal"     "DistMissVal" "remcoef"
# [16] "var"

# %%
set$VnDr$remcoef
set$VmissVal$missVal
# Out:
# [[1]]
# [[1]]$ar
# [1] 0.3583892
#
# [[1]]$order1
# [1] 1
#
# [[1]]$order2
# [1] 0
#
# [[1]]$order3
# [1] 0
#
#
# [[2]]
# [[2]]$order1
# [1] 0
#
# [[2]]$order2
# [1] 0
#
# [[2]]$order3
# [1] 0
#
#
# [[3]]
# [[3]]$order1
# [1] 0
#
# [[3]]$order2
# [1] 0
#
# [[3]]$order3
# [1] 0
#
#
# [[4]]
# [[4]]$order1
# [1] 0
#
# [[4]]$order2
# [1] 0
#
# [[4]]$order3
# [1] 0
#
#
# [[5]]
# [[5]]$ar
# [1] 0.04586597
#
# [[5]]$order1
# [1] 1
#
# [[5]]$order2
# [1] 0
#
# [[5]]$order3
# [1] 0
#
#
# [[6]]
# [[6]]$order1
# [1] 0
#
# [[6]]$order2
# [1] 0
#
# [[6]]$order3
# [1] 0
#
#
# [[7]]
# [[7]]$order1
# [1] 0
#
# [[7]]$order2
# [1] 0
#
# [[7]]$order3
# [1] 0
#
#
# [[8]]
# [[8]]$order1
# [1] 0
#
# [[8]]$order2
# [1] 0
#
# [[8]]$order3
# [1] 0
#
#
# [[9]]
# [[9]]$order1
# [1] 0
#
# [[9]]$order2
# [1] 0
#
# [[9]]$order3
# [1] 0
#
#
# [[10]]
# [[10]]$order1
# [1] 0
#
# [[10]]$order2
# [1] 0
#
# [[10]]$order3
# [1] 0
#
#
# [[11]]
# [[11]]$order1
# [1] 0
#
# [[11]]$order2
# [1] 0
#
# [[11]]$order3
# [1] 0
#
# ...
